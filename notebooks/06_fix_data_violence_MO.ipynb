# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
pth=Path('../missouri','violence.xls')
print(pth)
df=pd.read_excel(pth)
df.head()
# Out:
# ..\missouri\violence.xls
#         city  population  violent crime  murder  rape1  rape2  robbery  \
# 0     Adrian        1611            4.0       0      1    NaN        0
# 1    Advance        1369            1.0       0      0    NaN        0
# 2       Alma         392            0.0       0      0    NaN        0
# 3   Anderson        1980           13.0       0      1    NaN        1
# 4  Annapolis         343            0.0       0      0    NaN        0
#
#    aggravated assault  property crime  burglary  larceny theft  \
# 0                 3.0              35        12             21
# 1                 1.0               9         5              4
# 2                 0.0               1         0              1
# 3                11.0              56         5             42
# 4                 0.0               3         0              3
#
#    motor vehicle theft  arson
# 0                    2      0
# 1                    0      0
# 2                    0      0
# ...

# %%
df['vc per capita']=df['violent crime']/df['population']
df.head()
# Out:
#         city  population  violent crime  murder  rape1  rape2  robbery  \
# 0     Adrian        1611            4.0       0      1    NaN        0
# 1    Advance        1369            1.0       0      0    NaN        0
# 2       Alma         392            0.0       0      0    NaN        0
# 3   Anderson        1980           13.0       0      1    NaN        1
# 4  Annapolis         343            0.0       0      0    NaN        0
#
#    aggravated assault  property crime  burglary  larceny theft  \
# 0                 3.0              35        12             21
# 1                 1.0               9         5              4
# 2                 0.0               1         0              1
# 3                11.0              56         5             42
# 4                 0.0               3         0              3
#
#    motor vehicle theft  arson  vc per capital
# 0                    2      0        0.002483
# 1                    0      0        0.000730
# ...

# %%
df.to_csv('../missouri/violence_clean.csv',index=False)

# %%
df.describe()
# Out:
#           population  violent crime      murder       rape1  rape2  \
# count     418.000000     417.000000  418.000000  418.000000    0.0
# mean     8972.641148      60.244604    1.081340    4.631579    NaN
# std     31747.079334     499.693668   11.170923   29.098166    NaN
# min       123.000000       0.000000    0.000000    0.000000    NaN
# 25%       914.500000       1.000000    0.000000    0.000000    NaN
# 50%      2126.500000       5.000000    0.000000    0.000000    NaN
# 75%      6453.000000      19.000000    0.000000    1.000000    NaN
# max    478364.000000    7915.000000  188.000000  408.000000    NaN
#
#            robbery  aggravated assault  property crime     burglary  \
# count   418.000000          417.000000      418.000000   418.000000
# mean     14.217703           40.393285      328.753589    54.399522
# std     133.290843          330.755980     1602.213421   306.444170
# min       0.000000            0.000000        0.000000     0.000000
# ...
