# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
pthmerged=Path('../data','merged_data.csv')
dfmerged=pd.read_csv(pthmerged)
dfmerged.rename({'LSLs per 100k people ':'LSLs per 100k people'},inplace=True)
dfmerged.columns
# dfmerged
# Out:
# Index(['State', 'LSLs per 100k people', 'violent crime per 100k inhabitants'], dtype='object')

# %%
dfmerged.corr()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_15092\4054466057.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfmerged.corr()
#                                     LSLs per 100k people  \
# LSLs per 100k people                             1.00000
# violent crime per 100k inhabitants              -0.10495
#
#                                     violent crime per 100k inhabitants
# LSLs per 100k people                                          -0.10495
# violent crime per 100k inhabitants                             1.00000

# %%
# dfmerged.info()
# dfmerged.columns
dfmerged.plot.scatter('LSLs per 100k people','violent crime per 100k inhabitants')
# Out:
# <Axes: xlabel='LSLs per 100k people', ylabel='violent crime per 100k inhabitants'>
