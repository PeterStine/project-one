# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
pthmerged=Path('../data','merged_data.csv')
dfmerged=pd.read_csv(pthmerged)
dfmerged=dfmerged.rename({'LSLs per 100k people ':'LSLs per 100k people'})
dfmerged['theft_log']=np.log(dfmerged['theft'])
dfmerged['vehicle theft_log']=np.log(dfmerged['vehicle theft'])
dfmerged['LSLs per 100k people_log']=np.log(dfmerged['LSLs per 100k people'])
#
# mean_lsl=dfmerged['LSLs per 100k people'].mean()
# max_lsl=dfmerged['LSLs per 100k people'].max()
# min_lsl=dfmerged['LSLs per 100k people'].min()
# diff_lsl=max_lsl-min_lsl
# print(mean_lsl)
# dfmerged['LSLs per 100k people_mn']=(dfmerged['LSLs per 100k people']-mean_lsl)/diff_lsl
# dfmerged['LSLs per 100k people_minmax']=(dfmerged['LSLs per 100k people']-min_lsl)/diff_lsl
dfmerged.columns
# dfmerged
# Out:
# Index(['State', 'LSLs per 100k people', 'violent crime', 'murder', 'rape2',
#        'rape3', 'robbery', 'agg assault', 'ppty crime', 'burglary', 'theft',
#        'vehicle theft', 'theft_log', 'vehicle theft_log',
#        'LSLs per 100k people_log'],
#       dtype='object')

# %%
dfmerged.corr()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_7680\4054466057.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfmerged.corr()
#                           LSLs per 100k people  violent crime    murder  \
# LSLs per 100k people                  1.000000      -0.104950 -0.016367
# violent crime                        -0.104950       1.000000  0.702996
# murder                               -0.016367       0.702996  1.000000
# rape2                                -0.095217       0.576603  0.173845
# rape3                                -0.085925       0.577733  0.166651
# robbery                               0.000386       0.681043  0.667932
# agg assault                          -0.125457       0.968607  0.634598
# ppty crime                           -0.280118       0.625313  0.506737
# burglary                             -0.209409       0.608395  0.657999
# theft                                -0.268540       0.547144  0.437318
# vehicle theft                        -0.263504       0.561787  0.234960
# theft_log                            -0.250912       0.536597  0.450380
# vehicle theft_log                    -0.162259       0.571873  0.323355
# LSLs per 100k people_log              0.895236      -0.151583 -0.003234
#
#                              rape2     rape3   robbery  agg assault  \
# LSLs per 100k people     -0.095217 -0.085925  0.000386    -0.125457
# violent crime             0.576603  0.577733  0.681043     0.968607
# murder                    0.173845  0.166651  0.667932     0.634598
# rape2                     1.000000  0.999270  0.070153     0.576651
# rape3                     0.999270  1.000000  0.074241     0.576843
# robbery                   0.070153  0.074241  1.000000     0.498442
# agg assault               0.576651  0.576843  0.498442     1.000000
# ppty crime                0.459746  0.459950  0.361038     0.612820
# burglary                  0.303664  0.302439  0.397111     0.599137
# theft                     0.435055  0.433039  0.274893     0.546965
# vehicle theft             0.510540  0.520340  0.398106     0.509423
# theft_log                 0.417212  0.415756  0.280466     0.533267
# vehicle theft_log         0.471672  0.482832  0.401589     0.526445
# LSLs per 100k people_log -0.142171 -0.139442 -0.111245    -0.136515
#
#                           ppty crime  burglary     theft  vehicle theft  \
# LSLs per 100k people       -0.280118 -0.209409 -0.268540      -0.263504
# violent crime               0.625313  0.608395  0.547144       0.561787
# murder                      0.506737  0.657999  0.437318       0.234960
# rape2                       0.459746  0.303664  0.435055       0.510540
# rape3                       0.459950  0.302439  0.433039       0.520340
# robbery                     0.361038  0.397111  0.274893       0.398106
# agg assault                 0.612820  0.599137  0.546965       0.509423
# ppty crime                  1.000000  0.836731  0.969305       0.773792
# burglary                    0.836731  1.000000  0.716187       0.534802
# theft                       0.969305  0.716187  1.000000       0.681146
# vehicle theft               0.773792  0.534802  0.681146       1.000000
# theft_log                   0.965362  0.719030  0.995356       0.671947
# vehicle theft_log           0.789636  0.563787  0.710825       0.940087
# LSLs per 100k people_log   -0.349675 -0.227491 -0.313259      -0.453896
#
#                           theft_log  vehicle theft_log  \
# LSLs per 100k people      -0.250912          -0.162259
# violent crime              0.536597           0.571873
# murder                     0.450380           0.323355
# rape2                      0.417212           0.471672
# rape3                      0.415756           0.482832
# robbery                    0.280466           0.401589
# agg assault                0.533267           0.526445
# ppty crime                 0.965362           0.789636
# burglary                   0.719030           0.563787
# theft                      0.995356           0.710825
# vehicle theft              0.671947           0.940087
# theft_log                  1.000000           0.717630
# vehicle theft_log          0.717630           1.000000
# LSLs per 100k people_log  -0.301321          -0.348275
#
#                           LSLs per 100k people_log
# LSLs per 100k people                      0.895236
# violent crime                            -0.151583
# murder                                   -0.003234
# rape2                                    -0.142171
# rape3                                    -0.139442
# robbery                                  -0.111245
# agg assault                              -0.136515
# ppty crime                               -0.349675
# burglary                                 -0.227491
# theft                                    -0.313259
# vehicle theft                            -0.453896
# theft_log                                -0.301321
# vehicle theft_log                        -0.348275
# LSLs per 100k people_log                  1.000000

# %%
# dfmerged.info()
dfmerged.columns
# Out:
# Index(['State', 'LSLs per 100k people', 'violent crime', 'murder', 'rape2',
#        'rape3', 'robbery', 'agg assault', 'ppty crime', 'burglary', 'theft',
#        'vehicle theft', 'theft_log', 'vehicle theft_log',
#        'LSLs per 100k people_log'],
#       dtype='object')

# %%
dfmerged.plot.scatter('LSLs per 100k people','violent crime')
# Out:
# <Axes: xlabel='LSLs per 100k people', ylabel='violent crime'>

# %%
dfmerged.plot.scatter('LSLs per 100k people_log','vehicle theft')
# Out:
# <Axes: xlabel='LSLs per 100k people_log', ylabel='vehicle theft'>
