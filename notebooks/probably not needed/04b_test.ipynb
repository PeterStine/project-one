# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
pthmerged=Path('../data','merged_data.csv')
dfmerged=pd.read_csv(pthmerged)
dfmerged.rename({'LSLs per 100k people ':'LSLs per 100k people'},inplace=True)
dfmerged['violent crime per 100k inhabitants']=dfmerged['violent crime per 100k inhabitants'].astype(int)
# dfmerged['violent crime per 100k inhabitants']=int(dfmerged['violent crime per 100k inhabitants'])
# dfmerged['LSLs per 100k people']=np.log(dfmerged['LSLs per 100k people'])
# dfmerged['violent crime per 100k inhabitants']=np.log(dfmerged['violent crime per 100k inhabitants'])
# dfmerged.columns
dfmerged['LSLs per 100k people'].describe()
labels=['low','medium','high','very high']
bins=[163,923,1164,1813,5597]
dfmerged['LSLs binned']=pd.cut(dfmerged['LSLs per 100k people'],bins=bins,labels=labels)
dfmerged
# Out:
#              State  LSLs per 100k people  violent crime per 100k inhabitants  \
# 0          Alabama                  1254                                 532
# 1           Alaska                   518                                 804
# 2          Arizona                   168                                 470
# 3         Arkansas                  1328                                 550
# 4       California                   164                                 445
# 5         Colorado                  1120                                 342
# 6      Connecticut                  1192                                 227
# 7         Delaware                  1616                                 508
# 8          Florida                   929                                 430
# 9          Georgia                   803                                 397
# 10          Hawaii                   192                                 309
# ...

# %%
dfmerged.corr()
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_13436\4054466057.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfmerged.corr()
#                                     LSLs per 100k people  \
# LSLs per 100k people                             1.00000
# violent crime per 100k inhabitants              -0.10506
#
#                                     violent crime per 100k inhabitants
# LSLs per 100k people                                          -0.10506
# violent crime per 100k inhabitants                             1.00000

# %%
# dfmerged.info()
# dfmerged.columns
# dfmerged.plot.scatter('LSLs per 100k people','violent crime per 100k inhabitants')
dfmerged.sort_values('LSLs binned',inplace=True)
dfmerged.plot.bar('LSLs binned','violent crime per 100k inhabitants')
# Out:
# <Axes: xlabel='LSLs binned'>
